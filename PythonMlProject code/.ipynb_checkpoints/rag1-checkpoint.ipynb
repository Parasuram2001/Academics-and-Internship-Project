# %%
# -- coding: utf-8 --

# Form implementation generated from reading ui file 'hire.ui'
#
# Created by: PyQt5 UI code generator 5.9.2
#
# WARNING! All changes made in this file will be lost!

from PyQt5 import QtCore, QtGui, QtWidgets

class Ui_Form(object):
    def setupUi(self, Form):
        Form.setObjectName("Form")
        Form.resize(1182, 745)
        Form.setStyleSheet("color: rgb(255, 0, 0);\n"
"font: 75 8pt \"Myanmar Text\";\n"
"font: 20pt \"MS Shell Dlg 2\";\n"
"")
        self.label = QtWidgets.QLabel(Form)
        self.label.setGeometry(QtCore.QRect(440, 30, 391, 51))
        self.label.setObjectName("label")
        self.label_2 = QtWidgets.QLabel(Form)
        self.label_2.setGeometry(QtCore.QRect(80, 190, 151, 71))
        self.label_2.setStyleSheet("color: rgb(0, 85, 255);\n"
"font: 16pt \"MV Boli\";")
        self.label_2.setObjectName("label_2")
        self.label_3 = QtWidgets.QLabel(Form)
        self.label_3.setGeometry(QtCore.QRect(80, 320, 141, 71))
        self.label_3.setStyleSheet("color: rgb(0, 85, 255);\n"
"font: 16pt \"MV Boli\";")
        self.label_3.setObjectName("label_3")
        self.writtenoutput = QtWidgets.QLabel(Form)
        self.writtenoutput.setGeometry(QtCore.QRect(580, 180, 181, 71))
        self.writtenoutput.setStyleSheet("color: rgb(0, 85, 255);\n"
"font: 16pt \"MV Boli\";")
        self.writtenoutput.setObjectName("writtenoutput")
        self.aptitudeoutput = QtWidgets.QLabel(Form)
        self.aptitudeoutput.setGeometry(QtCore.QRect(580, 330, 181, 71))
        self.aptitudeoutput.setStyleSheet("color: rgb(0, 85, 255);\n"
"font: 16pt \"MV Boli\";")
        self.aptitudeoutput.setObjectName("aptitudeoutput")
        self.interviewoutput = QtWidgets.QLineEdit(Form)
        self.interviewoutput.setGeometry(QtCore.QRect(250, 200, 201, 61))
        self.interviewoutput.setObjectName("interviewoutput")
        self.cgpaoutput = QtWidgets.QLineEdit(Form)
        self.cgpaoutput.setGeometry(QtCore.QRect(250, 330, 201, 61))
        self.cgpaoutput.setObjectName("cgpaoutput")
        self.writtenoutput_2 = QtWidgets.QLineEdit(Form)
        self.writtenoutput_2.setGeometry(QtCore.QRect(770, 190, 201, 61))
        self.writtenoutput_2.setObjectName("writtenoutput_2")
        self.aptitudeouput = QtWidgets.QLineEdit(Form)
        self.aptitudeouput.setGeometry(QtCore.QRect(770, 340, 201, 61))
        self.aptitudeouput.setObjectName("aptitudeouput")
        self.pushButton = QtWidgets.QPushButton(Form)
        self.pushButton.setGeometry(QtCore.QRect(540, 440, 112, 34))
        self.pushButton.setStyleSheet("color:rgb(0, 0, 0);\n"
"font: 75 8pt \"MS Shell Dlg 2\";")
        self.pushButton.setObjectName("pushButton")
        self.Result = QtWidgets.QLineEdit(Form)
        self.Result.setGeometry(QtCore.QRect(450, 560, 331, 61))
        self.Result.setObjectName("Result")
        self.pushButton.clicked.connect(self.hire)
        

        self.retranslateUi(Form)
        QtCore.QMetaObject.connectSlotsByName(Form)
        
    def hire(self):
        Interview=self.interviewoutput.text()
        CGPA=self.cgpaoutput.text()
        Written=self.writtenoutput.text()
        Aptitude=self.aptitudeoutput.text()
        
        import pandas as pd
        path="C:\\Users\\parashuram\\Desktop\\ipro\\hiredornot.csv"
        data=pd.read_csv(path)
        #print(data)
        inputs=data.drop('Status','columns')
        print(inputs)
        output=data.drop(['Interview','CGPA','Written','Aptitude'],'columns')
        print("output",output)

        import sklearn
        from sklearn.model_selection import train_test_split
        
        x_train,x_test,y_train,y_test=train_test_split(inputs,output,test_size=0.2)
        #print(x_train)
        #print(x_test)
        #print(y_train)
        #print(y_test)
        from sklearn.neighbors import KNeighborsClassifier
        model=KNeighborsClassifier(n_neighbors=5)
        model.fit(x_train,y_train)
        y_pred=model.predict(x_test)
        print("y_pred",y_pred)
        print("y_test",y_test)
        #res=model.predict([[51,2,79,82]])
        #res=model.predict([[80,10,79,68]])
        res=model.predict([[int(Interview),int(CGPA),int(Written),int(Aptitude)]])
        print("result",res)
        self.result.setText(str(res))
        print("button is pressed")
        

    def retranslateUi(self, Form):
        _translate = QtCore.QCoreApplication.translate
        Form.setWindowTitle(_translate("Form", "Form"))
        self.label.setText(_translate("Form", "HIRED or NOT"))
        self.label_2.setText(_translate("Form", "Interview:"))
        self.label_3.setText(_translate("Form", "CGPA:"))
        self.writtenoutput.setText(_translate("Form", "Written:"))
        self.aptitudeoutput.setText(_translate("Form", "Aptitude:"))
        self.pushButton.setText(_translate("Form", "PushButton"))


if __name__ == "__main__":
    import sys
    app = QtWidgets.QApplication(sys.argv)
    Form = QtWidgets.QWidget()
    ui = Ui_Form()
    ui.setupUi(Form)
    Form.show()
    sys.exit(app.exec_())
# Out:
# C:\Users\parashuram\AppData\Local\Temp\ipykernel_1888\2680071574.py:78: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   inputs=data.drop('Status','columns')
# C:\Users\parashuram\AppData\Local\Temp\ipykernel_1888\2680071574.py:80: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   output=data.drop(['Interview','CGPA','Written','Aptitude'],'columns')
#     Interview  CGPA  Written  Aptitude
# 0          51     2       79        82
# 1          80    10       79        68
# 2          55     8       79        64
# 3          72     9       69        79
# 4          51     4       72        53
# 5          52     7       61        69
# 6          68     7       67        68
# 7          76     7       70        62
# 8          73     5       67        72
# 9          51     8       67        62
# ...

# %%
import pandas as pd
path="C:\\Users\\parashuram\\Desktop\\ipro\\hiredornot.csv"
data=pd.read_csv(path)
#print(data)
inputs=data.drop('Status','columns')
print(inputs)
output=data.drop(['Interview','CGPA','Written','Aptitude'],'columns')
print("output",output)

import sklearn
from sklearn.model_selection import train_test_split
        
x_train,x_test,y_train,y_test=train_test_split(inputs,output,test_size=0.2)
        #print(x_train)
        #print(x_test)
        #print(y_train)
        #print(y_test)
from sklearn.neighbors import KNeighborsClassifier
model=KneighbhourClassifier(n_neighbors=)
model.fot(x_train,y_train)
y_pred=model.predict(x_test)
print("y_pred",y_pred)
print("y_test",y_test)

#predict=model.predict([])

# %%
import pandas as pd
path="C:\\Users\\parashuram\\Desktop\\ipro\\hiredornot.csv"
data=pd.read_csv(path)
#print(data)
inputs=data.drop('Status','columns')
print(inputs)
output=data.drop(['Interview','CGPA','Written','Aptitude'],'columns')
print("output",output)

import sklearn
from sklearn.model_selection import train_test_split
        
x_train,x_test,y_train,y_test=train_test_split(inputs,output,test_size=0.2)
        #print(x_train)
        #print(x_test)
        #print(y_train)
        #print(y_test)
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier(n_neighbors=5)
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
print("y_pred",y_pred)
print("y_test",y_test)
#res=model.predict([[51,2,79,82]])
res=model.predict([[80,10,79,68]])
print("result",res)
# Out:
#     Interview  CGPA  Written  Aptitude
# 0          51     2       79        82
# 1          80    10       79        68
# 2          55     8       79        64
# 3          72     9       69        79
# 4          51     4       72        53
# 5          52     7       61        69
# 6          68     7       67        68
# 7          76     7       70        62
# 8          73     5       67        72
# 9          51     8       67        62
# 10         62     6       54        76
# 11         66     7       50        60
# 12         75     2       77        62
# 13         77     8       57        55
# 14         67     7       57        54
# 15         58     6       60        57
# 16         75     4       73        55
# 17         67     5       65        79
# 18         62     6       53        70
# 19         80     9       50        56
# 20         73     5       52        56
# 21         59     9       54        78
# 22         66     9       77        74
# ...
