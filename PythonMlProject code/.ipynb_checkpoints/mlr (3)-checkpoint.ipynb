# %%
import pandas as pd
path="C:\\Users\\parashuram\\Desktop\\ipro\\bodyfat.csv"
data=pd.read_csv(path)
#print(data)
inputs=data.drop("BodyFat","columns")
output=data.drop(["Density","Age","Weight","Height","Neck","Chest","Abdomen","Hip","Thigh","Knee","Ankle","Biceps","Forearm","Wrist"],"columns")
print(inputs)
print("output",output)

import sklearn
from sklearn import linear_model
model=linear_model.LinearRegression()
model.fit(inputs,output)
res=model.predict([[1.0708,23,154.25,67.75,36.2,93.1,85.2,94.5,59.0,37.3,21.9,32.0,27.4,17.1]])
print(res)
coef=model.coef_
print("coef",coef)
intercept=model.intercept_
print("intercept",intercept)
ther=(-4.11237849e+02*1.0708)+(1.25870031e-02*23)+(1.00541597e-02*154.25)+(-7.98073928e-03*67.75)+(-2.84558253e-02*36.2)+(2.67803354e-02*93.1)+(1.85648834e-02*85.2)+(1.91660401e-02*94.5)+(-1.67583631e-02*59.0)+(-4.63900522e-03*37.3)+(-8.56761181e-02*21.9)+(-5.50508219e-02*32.0)+(3.38634347e-02*27.4)+(7.34493756e-03*17.1)+450.01256934
print(ther)
# Out:
#      Density  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  Knee  \
# 0     1.0708   23  154.25   67.75  36.2   93.1     85.2   94.5   59.0  37.3
# 1     1.0853   22  173.25   72.25  38.5   93.6     83.0   98.7   58.7  37.3
# 2     1.0414   22  154.00   66.25  34.0   95.8     87.9   99.2   59.6  38.9
# 3     1.0751   26  184.75   72.25  37.4  101.8     86.4  101.2   60.1  37.3
# 4     1.0340   24  184.25   71.25  34.4   97.3    100.0  101.9   63.2  42.2
# ..       ...  ...     ...     ...   ...    ...      ...    ...    ...   ...
# 247   1.0736   70  134.25   67.00  34.9   89.2     83.6   88.8   49.6  34.8
# 248   1.0236   72  201.00   69.75  40.9  108.5    105.0  104.5   59.6  40.8
# 249   1.0328   72  186.75   66.00  38.9  111.1    111.5  101.7   60.3  37.3
# 250   1.0399   72  190.75   70.50  38.9  108.3    101.3   97.8   56.0  41.6
# 251   1.0271   74  207.50   70.00  40.8  112.4    108.5  107.1   59.3  42.2
#
#      Ankle  Biceps  Forearm  Wrist
# ...

# %%
# -*- coding: utf-8 -*-

# Form implementation generated from reading ui file 'bodyfat.ui'
#
# Created by: PyQt5 UI code generator 5.9.2
#
# WARNING! All changes made in this file will be lost!

from PyQt5 import QtCore, QtGui, QtWidgets

class Ui_Dialog(object):
    def setupUi(self, Dialog):
        Dialog.setObjectName("Dialog")
        Dialog.resize(1067, 737)
        self.label = QtWidgets.QLabel(Dialog)
        self.label.setGeometry(QtCore.QRect(300, 30, 521, 41))
        self.label.setStyleSheet("COLOR:rgb(255, 0, 0);\n"
"background-color: rgb(255, 255, 127);\n"
"font: 26pt \"MV Boli\";")
        self.label.setObjectName("label")
        self.label_2 = QtWidgets.QLabel(Dialog)
        self.label_2.setGeometry(QtCore.QRect(30, 140, 121, 31))
        self.label_2.setStyleSheet("color: rgb(0, 0, 127);\n"
"font: 75 14pt \"MS Shell Dlg 2\";\n"
"background-color: rgb(170, 170, 127);")
        self.label_2.setObjectName("label_2")
        self.label_3 = QtWidgets.QLabel(Dialog)
        self.label_3.setGeometry(QtCore.QRect(30, 200, 121, 31))
        self.label_3.setStyleSheet("color: rgb(0, 0, 127);\n"
"font: 75 14pt \"MS Shell Dlg 2\";\n"
"background-color: rgb(170, 170, 127);")
        self.label_3.setObjectName("label_3")
        self.label_4 = QtWidgets.QLabel(Dialog)
        self.label_4.setGeometry(QtCore.QRect(30, 260, 121, 31))
        self.label_4.setStyleSheet("color: rgb(0, 0, 127);\n"
"font: 75 14pt \"MS Shell Dlg 2\";\n"
"background-color: rgb(170, 170, 127);")
        self.label_4.setObjectName("label_4")
        self.label_5 = QtWidgets.QLabel(Dialog)
        self.label_5.setGeometry(QtCore.QRect(30, 320, 121, 31))
        self.label_5.setStyleSheet("color: rgb(0, 0, 127);\n"
"font: 75 14pt \"MS Shell Dlg 2\";\n"
"background-color: rgb(170, 170, 127);")
        self.label_5.setObjectName("label_5")
        self.label_6 = QtWidgets.QLabel(Dialog)
        self.label_6.setGeometry(QtCore.QRect(30, 380, 121, 31))
        self.label_6.setStyleSheet("color: rgb(0, 0, 127);\n"
"font: 75 14pt \"MS Shell Dlg 2\";\n"
"background-color: rgb(170, 170, 127);")
        self.label_6.setObjectName("label_6")
        self.label_7 = QtWidgets.QLabel(Dialog)
        self.label_7.setGeometry(QtCore.QRect(30, 440, 121, 31))
        self.label_7.setStyleSheet("color: rgb(0, 0, 127);\n"
"font: 75 14pt \"MS Shell Dlg 2\";\n"
"background-color: rgb(170, 170, 127);")
        self.label_7.setObjectName("label_7")
        self.label_8 = QtWidgets.QLabel(Dialog)
        self.label_8.setGeometry(QtCore.QRect(30, 500, 121, 31))
        self.label_8.setStyleSheet("color: rgb(0, 0, 127);\n"
"font: 75 14pt \"MS Shell Dlg 2\";\n"
"background-color: rgb(170, 170, 127);")
        self.label_8.setObjectName("label_8")
        self.label_9 = QtWidgets.QLabel(Dialog)
        self.label_9.setGeometry(QtCore.QRect(570, 140, 121, 31))
        self.label_9.setStyleSheet("color: rgb(0, 0, 127);\n"
"font: 75 14pt \"MS Shell Dlg 2\";\n"
"background-color: rgb(170, 170, 127);")
        self.label_9.setObjectName("label_9")
        self.label_10 = QtWidgets.QLabel(Dialog)
        self.label_10.setGeometry(QtCore.QRect(570, 200, 121, 31))
        self.label_10.setStyleSheet("color: rgb(0, 0, 127);\n"
"font: 75 14pt \"MS Shell Dlg 2\";\n"
"background-color: rgb(170, 170, 127);")
        self.label_10.setObjectName("label_10")
        self.label_11 = QtWidgets.QLabel(Dialog)
        self.label_11.setGeometry(QtCore.QRect(570, 260, 121, 31))
        self.label_11.setStyleSheet("color: rgb(0, 0, 127);\n"
"font: 75 14pt \"MS Shell Dlg 2\";\n"
"background-color: rgb(170, 170, 127);")
        self.label_11.setObjectName("label_11")
        self.label_12 = QtWidgets.QLabel(Dialog)
        self.label_12.setGeometry(QtCore.QRect(570, 320, 121, 31))
        self.label_12.setStyleSheet("color: rgb(0, 0, 127);\n"
"font: 75 14pt \"MS Shell Dlg 2\";\n"
"background-color: rgb(170, 170, 127);")
        self.label_12.setObjectName("label_12")
        self.label_13 = QtWidgets.QLabel(Dialog)
        self.label_13.setGeometry(QtCore.QRect(570, 380, 121, 31))
        self.label_13.setStyleSheet("color: rgb(0, 0, 127);\n"
"font: 75 14pt \"MS Shell Dlg 2\";\n"
"background-color: rgb(170, 170, 127);")
        self.label_13.setObjectName("label_13")
        self.label_14 = QtWidgets.QLabel(Dialog)
        self.label_14.setGeometry(QtCore.QRect(570, 440, 121, 31))
        self.label_14.setStyleSheet("color: rgb(0, 0, 127);\n"
"font: 75 14pt \"MS Shell Dlg 2\";\n"
"background-color: rgb(170, 170, 127);")
        self.label_14.setObjectName("label_14")
        self.label_15 = QtWidgets.QLabel(Dialog)
        self.label_15.setGeometry(QtCore.QRect(570, 500, 121, 31))
        self.label_15.setStyleSheet("color: rgb(0, 0, 127);\n"
"font: 75 14pt \"MS Shell Dlg 2\";\n"
"background-color: rgb(170, 170, 127);")
        self.label_15.setObjectName("label_15")
        self.density = QtWidgets.QLineEdit(Dialog)
        self.density.setGeometry(QtCore.QRect(200, 140, 141, 31))
        self.density.setObjectName("density")
        self.age = QtWidgets.QLineEdit(Dialog)
        self.age.setGeometry(QtCore.QRect(200, 200, 141, 31))
        self.age.setObjectName("age")
        self.weight = QtWidgets.QLineEdit(Dialog)
        self.weight.setGeometry(QtCore.QRect(200, 260, 141, 31))
        self.weight.setObjectName("weight")
        self.height = QtWidgets.QLineEdit(Dialog)
        self.height.setGeometry(QtCore.QRect(200, 320, 141, 31))
        self.height.setObjectName("height")
        self.neck = QtWidgets.QLineEdit(Dialog)
        self.neck.setGeometry(QtCore.QRect(200, 380, 141, 31))
        self.neck.setObjectName("neck")
        self.chest = QtWidgets.QLineEdit(Dialog)
        self.chest.setGeometry(QtCore.QRect(200, 440, 141, 31))
        self.chest.setObjectName("chest")
        self.abdomen = QtWidgets.QLineEdit(Dialog)
        self.abdomen.setGeometry(QtCore.QRect(200, 500, 141, 31))
        self.abdomen.setObjectName("abdomen")
        self.hip = QtWidgets.QLineEdit(Dialog)
        self.hip.setGeometry(QtCore.QRect(740, 140, 141, 31))
        self.hip.setObjectName("hip")
        self.thigh = QtWidgets.QLineEdit(Dialog)
        self.thigh.setGeometry(QtCore.QRect(740, 200, 141, 31))
        self.thigh.setObjectName("thigh")
        self.knee = QtWidgets.QLineEdit(Dialog)
        self.knee.setGeometry(QtCore.QRect(740, 260, 141, 31))
        self.knee.setObjectName("knee")
        self.ankle = QtWidgets.QLineEdit(Dialog)
        self.ankle.setGeometry(QtCore.QRect(740, 320, 141, 31))
        self.ankle.setObjectName("ankle")
        self.biceps = QtWidgets.QLineEdit(Dialog)
        self.biceps.setGeometry(QtCore.QRect(740, 380, 141, 31))
        self.biceps.setObjectName("biceps")
        self.forearm = QtWidgets.QLineEdit(Dialog)
        self.forearm.setGeometry(QtCore.QRect(740, 440, 141, 31))
        self.forearm.setObjectName("forearm")
        self.wrist = QtWidgets.QLineEdit(Dialog)
        self.wrist.setGeometry(QtCore.QRect(740, 500, 141, 31))
        self.wrist.setObjectName("wrist")
        self.pushButton = QtWidgets.QPushButton(Dialog)
        self.pushButton.setGeometry(QtCore.QRect(370, 550, 93, 28))
        self.pushButton.setObjectName("pushButton")
        self.result = QtWidgets.QLineEdit(Dialog)
        self.result.setGeometry(QtCore.QRect(290, 630, 241, 61))
        self.result.setObjectName("result")
        self.pushButton.clicked.connect(self.fat)

        self.retranslateUi(Dialog)
        QtCore.QMetaObject.connectSlotsByName(Dialog)
        
    def fat(self):
        Density=self.density.text()
        Age=self.age.text()
        Weight=self.weight.text()
        Height=self.height.text()
        Neck=self.neck.text()
        Chest=self.chest.text()
        Abdomen=self.abdomen.text()
        Hip=self.hip.text()
        Thigh=self.thigh.text()
        Knee=self.knee.text()
        Ankle=self.ankle.text()
        Biceps=self.biceps.text()
        Forearm=self.forearm.text()
        Wrist=self.wrist.text()
        
        import pandas as pd
        path="C:\\Users\\parashuram\\Desktop\\ipro\\bodyfat.csv"
        data=pd.read_csv(path)
#print(data)
        inputs=data.drop("BodyFat","columns")
        output=data.drop(["Density","Age","Weight","Height","Neck","Chest","Abdomen","Hip","Thigh","Knee","Ankle","Biceps","Forearm","Wrist"],"columns")
        print(inputs)
        print("output",output)

        import sklearn
        from sklearn import linear_model
        model=linear_model.LinearRegression()
        model.fit(inputs,output)
        #res=model.predict([[1.0708,23,154.25,67.75,36.2,93.1,85.2,94.5,59.0,37.3,21.9,32.0,27.4,17.1]])
        res=model.predict([[float(Density),float(Age),float(Weight),float(Height),float(Neck),float(Chest),float(Abdomen),float(Hip),float(Thigh),float(Knee),float(Ankle),float(Biceps),float(Forearm),float(Wrist)]])
        print(res)
        self.result.setText(str(res))
        print("button is pressed")


    def retranslateUi(self, Dialog):
        _translate = QtCore.QCoreApplication.translate
        Dialog.setWindowTitle(_translate("Dialog", "Dialog"))
        self.label.setText(_translate("Dialog", "BODY FAT PREDICTION"))
        self.label_2.setText(_translate("Dialog", "Density:"))
        self.label_3.setText(_translate("Dialog", "Age:"))
        self.label_4.setText(_translate("Dialog", "Weight:"))
        self.label_5.setText(_translate("Dialog", "Height:"))
        self.label_6.setText(_translate("Dialog", "Neck:"))
        self.label_7.setText(_translate("Dialog", "Chest:"))
        self.label_8.setText(_translate("Dialog", "Abdomen:"))
        self.label_9.setText(_translate("Dialog", "Hip:"))
        self.label_10.setText(_translate("Dialog", "Thigh:"))
        self.label_11.setText(_translate("Dialog", "Knee:"))
        self.label_12.setText(_translate("Dialog", "Ankle:"))
        self.label_13.setText(_translate("Dialog", "Biceps:"))
        self.label_14.setText(_translate("Dialog", "Forearm:"))
        self.label_15.setText(_translate("Dialog", "Wrist:"))
        self.pushButton.setText(_translate("Dialog", "PushButton"))


if __name__ == "__main__":
    import sys
    app = QtWidgets.QApplication(sys.argv)
    Dialog = QtWidgets.QDialog()
    ui = Ui_Dialog()
    ui.setupUi(Dialog)
    Dialog.show()
    sys.exit(app.exec_())
# Out:
# C:\Users\parashuram\AppData\Local\Temp\ipykernel_6268\401173800.py:178: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   inputs=data.drop("BodyFat","columns")
# C:\Users\parashuram\AppData\Local\Temp\ipykernel_6268\401173800.py:179: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   output=data.drop(["Density","Age","Weight","Height","Neck","Chest","Abdomen","Hip","Thigh","Knee","Ankle","Biceps","Forearm","Wrist"],"columns")
#      Density  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  Knee  \
# 0     1.0708   23  154.25   67.75  36.2   93.1     85.2   94.5   59.0  37.3
# 1     1.0853   22  173.25   72.25  38.5   93.6     83.0   98.7   58.7  37.3
# 2     1.0414   22  154.00   66.25  34.0   95.8     87.9   99.2   59.6  38.9
# 3     1.0751   26  184.75   72.25  37.4  101.8     86.4  101.2   60.1  37.3
# ...
