# %%
# -*- coding: utf-8 -*-

# Form implementation generated from reading ui file 'mobi.ui'
#
# Created by: PyQt5 UI code generator 5.9.2
#
# WARNING! All changes made in this file will be lost!

from PyQt5 import QtCore, QtGui, QtWidgets

class Ui_Form(object):
    def setupUi(self, Form):
        Form.setObjectName("Form")
        Form.resize(1101, 1111)
        self.label = QtWidgets.QLabel(Form)
        self.label.setGeometry(QtCore.QRect(390, 20, 331, 51))
        self.label.setStyleSheet("color: rgb(255, 0, 0);\n"
"text-decoration: underline;\n"
"font: 8pt \"MS Shell Dlg 2\";\n"
"font: italic 20pt \"Arial\";")
        self.label.setObjectName("label")
        self.label_2 = QtWidgets.QLabel(Form)
        self.label_2.setGeometry(QtCore.QRect(20, 100, 181, 41))
        self.label_2.setStyleSheet("color:rgb(0, 0, 255);\n"
"font: italic 14pt \"Arial\";")
        self.label_2.setObjectName("label_2")
        self.label_3 = QtWidgets.QLabel(Form)
        self.label_3.setGeometry(QtCore.QRect(20, 170, 181, 41))
        self.label_3.setStyleSheet("color:rgb(0, 0, 255);\n"
"font: italic 14pt \"Arial\";")
        self.label_3.setObjectName("label_3")
        self.label_4 = QtWidgets.QLabel(Form)
        self.label_4.setGeometry(QtCore.QRect(20, 250, 181, 41))
        self.label_4.setStyleSheet("color:rgb(0, 0, 255);\n"
"font: italic 14pt \"Arial\";")
        self.label_4.setObjectName("label_4")
        self.label_6 = QtWidgets.QLabel(Form)
        self.label_6.setGeometry(QtCore.QRect(570, 780, 181, 41))
        self.label_6.setStyleSheet("color:rgb(0, 0, 255);\n"
"font: italic 14pt \"Arial\";")
        self.label_6.setObjectName("label_6")
        self.label_7 = QtWidgets.QLabel(Form)
        self.label_7.setGeometry(QtCore.QRect(570, 710, 181, 41))
        self.label_7.setStyleSheet("color:rgb(0, 0, 255);\n"
"font: italic 14pt \"Arial\";")
        self.label_7.setObjectName("label_7")
        self.label_8 = QtWidgets.QLabel(Form)
        self.label_8.setGeometry(QtCore.QRect(570, 400, 181, 41))
        self.label_8.setStyleSheet("color:rgb(0, 0, 255);\n"
"font: italic 14pt \"Arial\";")
        self.label_8.setObjectName("label_8")
        self.label_9 = QtWidgets.QLabel(Form)
        self.label_9.setGeometry(QtCore.QRect(570, 480, 181, 41))
        self.label_9.setStyleSheet("color:rgb(0, 0, 255);\n"
"font: italic 14pt \"Arial\";")
        self.label_9.setObjectName("label_9")
        self.label_10 = QtWidgets.QLabel(Form)
        self.label_10.setGeometry(QtCore.QRect(570, 560, 181, 41))
        self.label_10.setStyleSheet("color:rgb(0, 0, 255);\n"
"font: italic 14pt \"Arial\";")
        self.label_10.setObjectName("label_10")
        self.label_11 = QtWidgets.QLabel(Form)
        self.label_11.setGeometry(QtCore.QRect(20, 570, 181, 41))
        self.label_11.setStyleSheet("color:rgb(0, 0, 255);\n"
"font: italic 14pt \"Arial\";")
        self.label_11.setObjectName("label_11")
        self.label_12 = QtWidgets.QLabel(Form)
        self.label_12.setGeometry(QtCore.QRect(20, 410, 181, 41))
        self.label_12.setStyleSheet("color:rgb(0, 0, 255);\n"
"font: italic 14pt \"Arial\";")
        self.label_12.setObjectName("label_12")
        self.label_13 = QtWidgets.QLabel(Form)
        self.label_13.setGeometry(QtCore.QRect(20, 330, 181, 41))
        self.label_13.setStyleSheet("color:rgb(0, 0, 255);\n"
"font: italic 14pt \"Arial\";")
        self.label_13.setObjectName("label_13")
        self.label_14 = QtWidgets.QLabel(Form)
        self.label_14.setGeometry(QtCore.QRect(20, 490, 181, 41))
        self.label_14.setStyleSheet("color:rgb(0, 0, 255);\n"
"font: italic 14pt \"Arial\";")
        self.label_14.setObjectName("label_14")
        self.label_15 = QtWidgets.QLabel(Form)
        self.label_15.setGeometry(QtCore.QRect(20, 640, 181, 41))
        self.label_15.setStyleSheet("color:rgb(0, 0, 255);\n"
"font: italic 14pt \"Arial\";")
        self.label_15.setObjectName("label_15")
        self.label_16 = QtWidgets.QLabel(Form)
        self.label_16.setGeometry(QtCore.QRect(570, 640, 181, 41))
        self.label_16.setStyleSheet("color:rgb(0, 0, 255);\n"
"font: italic 14pt \"Arial\";")
        self.label_16.setObjectName("label_16")
        self.label_17 = QtWidgets.QLabel(Form)
        self.label_17.setGeometry(QtCore.QRect(570, 100, 181, 41))
        self.label_17.setStyleSheet("color:rgb(0, 0, 255);\n"
"font: italic 14pt \"Arial\";")
        self.label_17.setObjectName("label_17")
        self.label_18 = QtWidgets.QLabel(Form)
        self.label_18.setGeometry(QtCore.QRect(570, 320, 181, 41))
        self.label_18.setStyleSheet("color:rgb(0, 0, 255);\n"
"font: italic 14pt \"Arial\";")
        self.label_18.setObjectName("label_18")
        self.label_19 = QtWidgets.QLabel(Form)
        self.label_19.setGeometry(QtCore.QRect(570, 170, 181, 41))
        self.label_19.setStyleSheet("color:rgb(0, 0, 255);\n"
"font: italic 14pt \"Arial\";")
        self.label_19.setObjectName("label_19")
        self.label_22 = QtWidgets.QLabel(Form)
        self.label_22.setGeometry(QtCore.QRect(570, 240, 181, 41))
        self.label_22.setStyleSheet("color:rgb(0, 0, 255);\n"
"font: italic 14pt \"Arial\";")
        self.label_22.setObjectName("label_22")
        self.label_24 = QtWidgets.QLabel(Form)
        self.label_24.setGeometry(QtCore.QRect(20, 790, 181, 41))
        self.label_24.setStyleSheet("color:rgb(0, 0, 255);\n"
"font: italic 14pt \"Arial\";")
        self.label_24.setObjectName("label_24")
        self.label_25 = QtWidgets.QLabel(Form)
        self.label_25.setGeometry(QtCore.QRect(20, 710, 181, 41))
        self.label_25.setStyleSheet("color:rgb(0, 0, 255);\n"
"font: italic 14pt \"Arial\";")
        self.label_25.setObjectName("label_25")
        self.batterypower = QtWidgets.QLineEdit(Form)
        self.batterypower.setGeometry(QtCore.QRect(230, 100, 251, 41))
        self.batterypower.setStyleSheet("font: italic 20pt \"Arial\";")
        self.batterypower.setText("")
        self.batterypower.setObjectName("batterypower")
        self.blue = QtWidgets.QLineEdit(Form)
        self.blue.setGeometry(QtCore.QRect(230, 170, 251, 41))
        self.blue.setStyleSheet("font: italic 20pt \"Arial\";")
        self.blue.setText("")
        self.blue.setObjectName("blue")
        self.clockspeed = QtWidgets.QLineEdit(Form)
        self.clockspeed.setGeometry(QtCore.QRect(230, 250, 251, 41))
        self.clockspeed.setStyleSheet("font: italic 20pt \"Arial\";")
        self.clockspeed.setText("")
        self.clockspeed.setObjectName("clockspeed")
        self.dualslim = QtWidgets.QLineEdit(Form)
        self.dualslim.setGeometry(QtCore.QRect(230, 330, 251, 41))
        self.dualslim.setStyleSheet("font: italic 20pt \"Arial\";")
        self.dualslim.setText("")
        self.dualslim.setObjectName("dualslim")
        self.fc = QtWidgets.QLineEdit(Form)
        self.fc.setGeometry(QtCore.QRect(230, 410, 251, 41))
        self.fc.setStyleSheet("font: italic 20pt \"Arial\";")
        self.fc.setText("")
        self.fc.setObjectName("fc")
        self.fourg = QtWidgets.QLineEdit(Form)
        self.fourg.setGeometry(QtCore.QRect(230, 490, 251, 41))
        self.fourg.setStyleSheet("font: italic 20pt \"Arial\";")
        self.fourg.setText("")
        self.fourg.setObjectName("fourg")
        self.intmemory = QtWidgets.QLineEdit(Form)
        self.intmemory.setGeometry(QtCore.QRect(230, 570, 251, 41))
        self.intmemory.setStyleSheet("font: italic 20pt \"Arial\";")
        self.intmemory.setText("")
        self.intmemory.setObjectName("intmemory")
        self.mdep = QtWidgets.QLineEdit(Form)
        self.mdep.setGeometry(QtCore.QRect(230, 640, 251, 41))
        self.mdep.setStyleSheet("font: italic 20pt \"Arial\";")
        self.mdep.setText("")
        self.mdep.setObjectName("mdep")
        self.mobilewt = QtWidgets.QLineEdit(Form)
        self.mobilewt.setGeometry(QtCore.QRect(230, 710, 251, 41))
        self.mobilewt.setStyleSheet("font: italic 20pt \"Arial\";")
        self.mobilewt.setText("")
        self.mobilewt.setObjectName("mobilewt")
        self.ncores = QtWidgets.QLineEdit(Form)
        self.ncores.setGeometry(QtCore.QRect(230, 790, 251, 41))
        self.ncores.setStyleSheet("font: italic 20pt \"Arial\";")
        self.ncores.setText("")
        self.ncores.setObjectName("ncores")
        self.pc = QtWidgets.QLineEdit(Form)
        self.pc.setGeometry(QtCore.QRect(760, 100, 251, 41))
        self.pc.setStyleSheet("font: italic 20pt \"Arial\";")
        self.pc.setText("")
        self.pc.setObjectName("pc")
        self.pxheight = QtWidgets.QLineEdit(Form)
        self.pxheight.setGeometry(QtCore.QRect(760, 170, 251, 41))
        self.pxheight.setStyleSheet("font: italic 20pt \"Arial\";")
        self.pxheight.setText("")
        self.pxheight.setObjectName("pxheight")
        self.pxwidth = QtWidgets.QLineEdit(Form)
        self.pxwidth.setGeometry(QtCore.QRect(760, 240, 251, 41))
        self.pxwidth.setStyleSheet("font: italic 20pt \"Arial\";")
        self.pxwidth.setText("")
        self.pxwidth.setObjectName("pxwidth")
        self.ram = QtWidgets.QLineEdit(Form)
        self.ram.setGeometry(QtCore.QRect(760, 320, 251, 41))
        self.ram.setStyleSheet("font: italic 20pt \"Arial\";")
        self.ram.setText("")
        self.ram.setObjectName("ram")
        self.sch = QtWidgets.QLineEdit(Form)
        self.sch.setGeometry(QtCore.QRect(760, 400, 251, 41))
        self.sch.setStyleSheet("font: italic 20pt \"Arial\";")
        self.sch.setText("")
        self.sch.setObjectName("sch")
        self.scw = QtWidgets.QLineEdit(Form)
        self.scw.setGeometry(QtCore.QRect(760, 480, 251, 41))
        self.scw.setStyleSheet("font: italic 20pt \"Arial\";")
        self.scw.setText("")
        self.scw.setObjectName("scw")
        self.talktime = QtWidgets.QLineEdit(Form)
        self.talktime.setGeometry(QtCore.QRect(760, 560, 251, 41))
        self.talktime.setStyleSheet("font: italic 20pt \"Arial\";")
        self.talktime.setText("")
        self.talktime.setObjectName("talktime")
        self.threeg = QtWidgets.QLineEdit(Form)
        self.threeg.setGeometry(QtCore.QRect(760, 640, 251, 41))
        self.threeg.setStyleSheet("font: italic 20pt \"Arial\";")
        self.threeg.setText("")
        self.threeg.setObjectName("threeg")
        self.touchscreen = QtWidgets.QLineEdit(Form)
        self.touchscreen.setGeometry(QtCore.QRect(760, 710, 251, 41))
        self.touchscreen.setStyleSheet("font: italic 20pt \"Arial\";")
        self.touchscreen.setText("")
        self.touchscreen.setObjectName("touchscreen")
        self.wifi = QtWidgets.QLineEdit(Form)
        self.wifi.setGeometry(QtCore.QRect(760, 780, 251, 41))
        self.wifi.setStyleSheet("font: italic 20pt \"Arial\";")
        self.wifi.setText("")
        self.wifi.setObjectName("wifi")
        self.pushButton = QtWidgets.QPushButton(Form)
        self.pushButton.setGeometry(QtCore.QRect(500, 880, 181, 61))
        self.pushButton.setObjectName("pushButton")
        self.result = QtWidgets.QLabel(Form)
        self.result.setGeometry(QtCore.QRect(130, 960, 271, 71))
        self.result.setStyleSheet("color:rgb(255, 0, 0);\n"
"font: italic 26pt \"Arial\";")
        self.result.setObjectName("result")
        self.pushButton.clicked.connect(self.mobi)

        self.retranslateUi(Form)
        QtCore.QMetaObject.connectSlotsByName(Form)
        
    def mobi(self):
        Batterypower=self.batterypower.text()
        Blue=self.blue.text()
        Clockspeed=self.clockspeed.text()
        Dualsim=self.dualslim.text()
        FC=self.fc.text()
        Fourg=self.fourg.text()
        Intmemory=self.intmemory.text()
        Mdep=self.mdep.text()
        Mobilewt=self.mobilewt.text()
        Ncores=self.ncores.text()
        PC=self.pc.text()
        Pxheight=self.pxheight.text()
        Pxwidth=self.pxwidth.text()
        Ram=self.ram.text()
        Sch=self.sch.text()
        Scw=self.scw.text()
        Talktime=self.talktime.text()
        Threeg=self.threeg.text()
        Touchscreen=self.touchscreen.text()
        Wifi=self.wifi.text()
        
        
        import pandas as pd
        path="C:\\Users\\parashuram\\Desktop\\ipro\\train.csv"
        data=pd.read_csv(path)
        print(data)

        inputs=data.drop("price_range","columns")
        outputs=data.drop(["battery_power","blue","clock_speed","dual_sim","fc","four_g","int_memory","m_dep","mobile_wt","n_cores","pc","px_height","px_width","ram","sc_h","sc_w","talk_time","three_g","touch_screen","wifi"],"columns")
        print(inputs)
        print("outputs",outputs)

        import sklearn
        from sklearn.model_selection import train_test_split
        x_train,x_test,y_train,y_test=train_test_split(inputs,outputs,test_size=0.2)
        print(x_train)
        print(x_test)
        print(y_train)
        print(y_test)

        import sklearn
        from sklearn.neighbors import KNeighborsClassifier
        model=KNeighborsClassifier(n_neighbors=45)
        model.fit(x_train,y_train)
        y_pred=model.predict(x_test)
        print("y_pred",y_pred)
        print("y_test",y_test)

        #predict=model.predict([[563,1,0.5,1,2,1,41,0.9,145,5,6,1263,1716,2603,11,2,9,1,1,0]])
        predict=model.predict([[int(Batterypower),int(Blue),float(Clockspeed),int(Dualsim),int(FC),int(Fourg),int(Intmemory),float(Mdep),int(Mobilewt),int(Ncores),int(PC),int(Pxheight),int(Pxwidth),int(Ram),int(Sch),int(Scw),int(Talktime),int(Threeg),int(Touchscreen),int(Wifi)]])
        print("predict",predict)
        self.result.setText(str(predict))

        

        
        print("button is pressed")

    def retranslateUi(self, Form):
        _translate = QtCore.QCoreApplication.translate
        Form.setWindowTitle(_translate("Form", "Form"))
        self.label.setText(_translate("Form", "Mobile price range"))
        self.label_2.setText(_translate("Form", "Batterypower"))
        self.label_3.setText(_translate("Form", "Blue"))
        self.label_4.setText(_translate("Form", "Clockspeed"))
        self.label_6.setText(_translate("Form", "Wifi"))
        self.label_7.setText(_translate("Form", "Touchscreen"))
        self.label_8.setText(_translate("Form", "Sch"))
        self.label_9.setText(_translate("Form", "Scw"))
        self.label_10.setText(_translate("Form", "Talktime"))
        self.label_11.setText(_translate("Form", "Intmemory"))
        self.label_12.setText(_translate("Form", "FC"))
        self.label_13.setText(_translate("Form", "Dualsim"))
        self.label_14.setText(_translate("Form", "Fourg"))
        self.label_15.setText(_translate("Form", "Mdep"))
        self.label_16.setText(_translate("Form", "Threeg"))
        self.label_17.setText(_translate("Form", "PC"))
        self.label_18.setText(_translate("Form", "Ram"))
        self.label_19.setText(_translate("Form", "Pxheight"))
        self.label_22.setText(_translate("Form", "Pxwidth"))
        self.label_24.setText(_translate("Form", "Ncores"))
        self.label_25.setText(_translate("Form", "Mobilewt"))
        self.pushButton.setText(_translate("Form", "PushButton"))
        self.result.setText(_translate("Form", "Result"))


if __name__ == "__main__":
    import sys
    app = QtWidgets.QApplication(sys.argv)
    Form = QtWidgets.QWidget()
    ui = Ui_Form()
    ui.setupUi(Form)
    Form.show()
    sys.exit(app.exec_())
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
import pandas as pd
path="C:\\Users\\parashuram\\Desktop\\ipro\\train.csv"
data=pd.read_csv(path)
print(data)

inputs=data.drop("price_range","columns")
outputs=data.drop(["battery_power","blue","clock_speed","dual_sim","fc","four_g","int_memory","m_dep","mobile_wt","n_cores","pc","px_height","px_width","ram","sc_h","sc_w","talk_time","three_g","touch_screen","wifi"],"columns")
print(inputs)
print("outputs",outputs)

import sklearn
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(inputs,outputs,test_size=0.2)
print(x_train)
print(x_test)
print(y_train)
print(y_test)

import sklearn
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier(n_neighbors=45)
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
print("y_pred",y_pred)
print("y_test",y_test)

predict=model.predict([[563,1,0.5,1,2,1,41,0.9,145,5,6,1263,1716,2603,11,2,9,1,1,0]])
#predict=model.predict([[int(Batterypower),int(Blue),float(Clockspeed),int(Dualsim),int(FC),int(Fourg),int(Intmemory),float(Mdep),int(Mobilewt),int(Ncores),int(PC),int(Pxheight),int(Pxwidth),int(Ram),int(Sch),int(Scw),int(Talktime),int(Threeg),int(Touchscreen),int(Wifi)]])
print("predict",predict)
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...
